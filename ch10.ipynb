# %% [markdown]
# ##知識を一つにまとめる

# %% [markdown]
# ###ハングマン

# %%
def hangman(word):
    wrong=0
    stages=["",
           "______     ",
           "|          ",
           "|    |     ",
           "|    0     ",
           "|   /|\    ",
           "|   / \    ",
           "|          "
           ]
    rletters=list(word)
    board=['_']*len(word)
    win=False
    print('ハングマンへようこそ!')

    while wrong<len(stages)-1:
        print('\n')
        msg='1文字を予想してね'
        char=input(msg)
        if char in rletters:
            c_idx=rletters.index(char)
            board[c_idx]=char
            rletters[c_idx]='$'
        else:
            wrong+=1
        print(''.join(board))
        e=wrong+1
        print('\n'.join(stages[0:e]))
        
        if '_' not in board:
            print('あなたの勝ち!')
            print(''.join(board))
            win=True
            break

    if not win:
        print('\n'.join(stages[0:wrong+1]))
        print('あなたの負け!正解は{}'.format(word))

# %%
hangman('cat')
# Out:
# ハングマンへようこそ!
#
#
# 1文字を予想してねt
# __t
#
#
#
# 1文字を予想してねd
# __t
#
# ______
#
#
# 1文字を予想してねv
# __t
#
# ______
# |
#
#
# 1文字を予想してねb
# __t
#
# ______
# |
# |    |
#
#
# 1文字を予想してねy
# __t
#
# ______
# |
# |    |
# |    0
#
#
# 1文字を予想してねy
# __t
#
# ______
# |
# |    |
# |    0
# |   /|\
#
#
# 1文字を予想してねh
# __t
#
# ______
# |
# |    |
# |    0
# |   /|\
# |   / \
#
#
# 1文字を予想してねh
# __t
#
# ______
# |
# |    |
# |    0
# |   /|\
# |   / \
# |
#
# ______
# |
# |    |
# |    0
# |   /|\
# |   / \
# |
# あなたの負け!正解はcat

# %%
hangman('dog')
# Out:
# ハングマンへようこそ!
#
#
# 1文字を予想してねd
# d__
#
#
#
# 1文字を予想してねg
# d_g
#
#
#
# 1文字を予想してねo
# dog
#
# あなたの勝ち!
# dog

# %% [markdown]
# ##チャレンジ

# %% [markdown]
# ###1．プログラムを書き換えて、答えの単語をリストからランダムに選ぶようにしよう。

# %%
import random

def hangman_rand():
    word_list=['dog','cat','horse','cow','fox','mouse','bird','rabbit',
               'bear','panda','penguin','human']
    word=random.choice(word_list)
    wrong=0
    stages=["",
           "______     ",
           "|          ",
           "|    |     ",
           "|    0     ",
           "|   /|\    ",
           "|   / \    ",
           "|          "
           ]
    rletters=list(word)
    board=['_']*len(word)
    win=False
    print('ハングマンへようこそ!')

    while wrong<len(stages)-1:
        print('\n')
        msg='1文字を予想してね'
        char=input(msg)
        if char in rletters:
            c_idx=rletters.index(char)
            board[c_idx]=char
            rletters[c_idx]='$'
        else:
            wrong+=1
        print(''.join(board))
        e=wrong+1
        print('\n'.join(stages[0:e]))
        
        if '_' not in board:
            print('あなたの勝ち!')
            print(''.join(board))
            win=True
            break

    if not win:
        print('\n'.join(stages[0:wrong+1]))
        print('あなたの負け!正解は{}'.format(word))

# %%
hangman_rand()
# Out:
# ハングマンへようこそ!
#
#
# 1文字を予想してねh
# ___
#
# ______
#
#
# 1文字を予想してねc
# ___
#
# ______
# |
#
#
# 1文字を予想してねd
# d__
#
# ______
# |
#
#
# 1文字を予想してねo
# do_
#
# ______
# |
#
#
# 1文字を予想してねg
# dog
#
# ______
# |
# あなたの勝ち!
# dog
