# %% [markdown]
# ##正規表現
# https://docs.python.org/ja/3/library/re.html

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ###シンプルな一致

# %%
import re

zen="""The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

matches=re.findall('Beautiful',zen) #一致する文字列を検索
print(matches)
# Out:
# ['Beautiful']

# %%
matches=re.findall("beautiful",zen,re.IGNORECASE)   #re.IGNORECASEで大文字小文字を区別しない
print(matches)
# Out:
# ['Beautiful']

# %%
matches=re.findall("i...",zen,re.IGNORECASE)   #'.'はどんな文字にも一致する
print(matches)
# Out:
# ['im P', 'iful', 'is b', 'icit', 'is b', 'impl', 'icit', 'impl', 'is b', 'is b', 'icat', 'is b', 'is b', 'ilit', 'ial ', 'ial ', 'ical', 'ity ', 'ity.', 'ilen', 'icit', 'ilen', 'In t', 'igui', 'ion ', 'ious', 'ious', 'irst', 'is b', 'is o', 'ight', 'If t', 'impl', 'ion ', 'is h', 'in, ', "it's", 'idea', 'If t', 'impl', 'ion ', 'is e', 'in, ', 'it m', 'idea', 'ing ', 'idea']

# %% [markdown]
# ###前方一致と後方一致

# %%
matches=re.findall("^If",zen,re.MULTILINE)   #'^'は行の先頭にある場合のみ一致.re.MULTILINEは複数行のテキストとして扱うためのフラグ
print(matches)
# Out:
# ['If', 'If']

# %%
matches=re.findall("idea.$",zen,re.MULTILINE)   #'$'は行の末尾にある場合のみ一致.re.MULTILINEは複数行のテキストとして扱うためのフラグ
print(matches)
# Out:
# ['idea.', 'idea.']

# %% [markdown]
# ###複数文字との一致

# %%
string='Two too.'

matches=re.findall("t[wo]o",string,re.IGNORECASE)   #[ ]内の文字列はどれかに一致する
print(matches)
# Out:
# ['Two', 'too']

# %% [markdown]
# ###数値との一致

# %%
line='123 hi 34 hello.'

matches=re.findall("\d",line,re.IGNORECASE)   #"\d"は数値に一致する
print(matches)
# Out:
# ['1', '2', '3', '3', '4']

# %% [markdown]
# ###繰り返し

# %%
t='__hello__hi__fuga'

matches=re.findall("__.*__",t,re.IGNORECASE)   #貪欲な一致
print(matches)
# Out:
# ['__hello__hi__']

# %%
t='__hello__hi__fuga'

matches=re.findall("__.*?__",t,re.IGNORECASE)   #非貪欲な一致
print(matches)
# Out:
# ['__hello__']

# %% [markdown]
# ##チャレンジ

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
t='The ghost that says boo haunts the loo'

matches=re.findall(".o{2}",t,re.IGNORECASE)
print(matches)
# Out:
# ['boo', 'loo']
